# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/deepseek-ai/DeepSeek-R1-0528',
#  '/Qwen/Qwen3-Embedding-0.6B-GGUF',
#  '/google/gemma-3n-E4B-it-litert-preview',
#  '/ResembleAI/chatterbox',
#  '/fishaudio/openaudio-s1-mini',
#  '/models',
#  '/spaces/ResembleAI/Chatterbox',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/multimodalart/wan2-1-fast',
#  '/spaces/alexnasa/Chain-of-Zoom',
#  '/spaces/NihalGazi/Text-To-Speech-Unlimited',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/open-thoughts/OpenThoughts3-1.2M',
#  '/datasets/yandex/yambda',
#  '/datasets/Hcompany/WebClick',
#  '/datasets/a-m-team/AM-DeepSeek-R1-0528-Distilled',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1-0528
# Updated
# 11 days ago
# •
# 97.1k
# •
# 1.88k
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# about 18 hours ago
# •
# 8.45k
# •
# 257
# google/gemma-3n-E4B-it-litert-preview
# Updated
# 15 days ago
# •
# 1.05k
# ResembleAI/chatterbox
# Updated
# 11 days ago
# •
# 732
# fishaudio/openaudio-s1-mini
# Updated
# 7 days ago
# •
# 1.25k
# •
# 182
# Browse 1M+ models
# Spaces
# Running
# on
# Zero
# 926
# 926
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Running
# 7.84k
# 7.84k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 575
# 575
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# on
# Zero
# 236
# 236
# Chain-of-Zoom
# 🚀
# Extreme Super-Resolution via Scale Autoregression
# Running
# 478
# 478
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 20.9k
# •
# 7.89k
# open-thoughts/OpenThoughts3-1.2M
# Updated
# about 7 hours ago
# •
# 3.7k
# •
# 68
# yandex/yambda
# Updated
# 3 days ago
# •
# 39.6k
# •
# 153
# Hcompany/WebClick
# Updated
# about 7 hours ago
# •
# 3.56k
# •
# 45
# a-m-team/AM-DeepSeek-R1-0528-Distilled
# Updated
# about 9 hours ago
# •
# 2.5k
# •
# 44
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 765 models
# •
# 3.39k followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.35k followers
# Amazon
# company
# •
# 20 models
# •
# 3.22k followers
# Google
# company
# •
# 997 models
# •
# 16.2k followers
# Intel
# company
# •
# 230 models
# •
# 2.62k followers
# Microsoft
# company
# •
# 386 models
# •
# 12.8k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 294 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,366
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,298
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,298
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,675
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,774
# Fast tokenizers optimized for research & production
# TRL
# 14,097
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,766
# State-of-the-art ML running directly in your browser
# smolagents
# 19,925
# Smol library to build great agents in Python
# PEFT
# 18,712
# Parameter-efficient finetuning for large language models
# Datasets
# 20,257
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,198
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,814
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1-0528
# Updated
# 11 days ago
# •
# 97.1k
# •
# 1.88k
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# about 18 hours ago
# •
# 8.45k
# •
# 257
# google/gemma-3n-E4B-it-litert-preview
# Updated
# 15 days ago
# •
# 1.05k
# ResembleAI/chatterbox
# Updated
# 11 days ago
# •
# 732
# fishaudio/openaudio-s1-mini
# Updated
# 7 days ago
# •
# 1.25k
# •
# 182
# Browse 1M+ models
# Spaces
# Running
# on
# Zero
# 926
# 926
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Running
# 7.84k
# 7.84k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 575
# 575
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# on
# Zero
# 236
# 236
# Chain-of-Zoom
# 🚀
# Extreme Super-Resolution via Scale Autoregression
# Running
# 478
# 478
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 20.9k
# •
# 7.89k
# open-thoughts/OpenThoughts3-1.2M
# Updated
# about 7 hours ago
# •
# 3.7k
# •
# 68
# yandex/yambda
# Updated
# 3 days ago
# •
# 39.6k
# •
# 153
# Hcompany/WebClick
# Updated
# about 7 hours ago
# •
# 3.56k
# •
# 45
# a-m-team/AM-DeepSeek-R1-0528-Distilled
# Updated
# about 9 hours ago
# •
# 2.5k
# •
# 44
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 765 models
# •
# 3.39k followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.35k followers
# Amazon
# company
# •
# 20 models
# •
# 3.22k followers
# Google
# company
# •
# 997 models
# •
# 16.2k followers
# Intel
# company
# •
# 230 models
# •
# 2.62k followers
# Microsoft
# company
# •
# 386 models
# •
# 12.8k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 294 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,366
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,298
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,298
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,675
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,774
# Fast tokenizers optimized for research & production
# TRL
# 14,097
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,766
# State-of-the-art ML running directly in your browser
# smolagents
# 19,925
# Smol library to build great agents in Python
# PEFT
# 18,712
# Parameter-efficient finetuning for large language models
# Datasets
# 20,257
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,198
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,814
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# from $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 393 models
# •
# 28.5k followers
# Shopify
# Enterprise
# company
# •
# 476 followers
# AMD
# Enterprise
# company
# •
# 142 models
# •
# 1.58k followers
# Arm
# Enterprise
# company
# •
# 213 followers
# Qwen
# Enterprise
# company
# •
# 289 models
# •
# 34.2k followers
# Xsolla
# Enterprise
# company
# •
# 137 followers
# Fidelity Investments
# Enterprise
# company
# •
# 150 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 166 followers
# IBM Granite
# Enterprise
# company
# •
# 118 models
# •
# 1.85k followers
# Aledade Inc
# Enterprise
# company
# •
# 72 followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# MiniMax
# Enterprise
# company
# •
# 5 models
# •
# 725 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 861 followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.35k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 536 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 294 followers
# ServiceNow
# Enterprise
# company
# •
# 509 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 287 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 118 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 70 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 426 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 74 followers
# LinkedIn
# Enterprise
# company
# •
# 60 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 1.04k followers
# Stability AI
# Enterprise
# company
# •
# 107 models
# •
# 24.8k followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 47.3k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 300 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 230 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 619 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 110 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 150 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 4 models
# •
# 154 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.43k followers
# Johnson & Johnson
# Enterprise
# company
# •
# 67 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 341 followers
# Skywork
# Enterprise
# company
# •
# 40 models
# •
# 715 followers
# Liquid AI
# Enterprise
# company
# •
# 199 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# PRO Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# 10× Private storage capacity
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 8× more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# ZeroGPU
# : Get 8× usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 26
# Community Articles
# view all
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 6 days ago
# •
# 61
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 3 days ago
# •
# 26
# Explore, Build, and Innovate AI Reasoning with NVIDIA’s Open Models and Recipes
# By
# nvidia
# and 2 others
# •
# 5 days ago
# •
# 19
# *Context Is Gold to Find the Gold Passage*:  Evaluating and Training Contextual Document Embeddings
# By
# manu
# and 1 other
# •
# 7 days ago
# •
# 23
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 3 days ago
# •
# 13
# xLSTM-based time series model TiRex  significantly outperforms competing models in forecasting accuracy
# By
# BobWue
# •
# 5 days ago
# •
# 12
# What if Your AI Conversations Become Public?
# By
# fdaudens
# •
# 3 days ago
# •
# 10
# Daily Robotics June #1 - SmolVLA discovery and thoughts
# By
# Beegbrain
# •
# 6 days ago
# •
# 9
# AI Policy @🤗: Response to the 2025 National AI R&D Strategic Plan
# By
# evijit
# and 2 others
# •
# 7 days ago
# •
# 12
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 150
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 330
# Google Opensources Deep Research Agents using Gemini 2.5 & LangGraph, Let's Take a Look
# By
# lynn-mikami
# •
# 6 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 607
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 187
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 284
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 12 days ago
# •
# 20
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 89
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 41
# System Prompt Learning: Teaching LLMs to Learn Problem-Solving Strategies from Experience
# By
# codelion
# •
# 8 days ago
# •
# 10
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 142
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 59
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 107
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 39
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 50
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 36
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 18
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 122
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 33
# nanoVLM: The simplest repository to train your VLM in pure PyTorch
# By
# ariG23498
# May 21, 2025
# •
# 144
# Microsoft and Hugging Face expand collaboration
# By
# jeffboudier
# May 19, 2025
# •
# 21
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 112
# Improving Hugging Face Model Access for Kaggle Users
# By
# roseberryv
# May 14, 2025
# •
# 28
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 68
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 427
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 6 days ago
# •
# 61
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 3 days ago
# •
# 26
# Explore, Build, and Innovate AI Reasoning with NVIDIA’s Open Models and Recipes
# By
# nvidia
# and 2 others
# •
# 5 days ago
# •
# 19
# *Context Is Gold to Find the Gold Passage*:  Evaluating and Training Contextual Document Embeddings
# By
# manu
# and 1 other
# •
# 7 days ago
# •
# 23
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 3 days ago
# •
# 13
# xLSTM-based time series model TiRex  significantly outperforms competing models in forecasting accuracy
# By
# BobWue
# •
# 5 days ago
# •
# 12
# What if Your AI Conversations Become Public?
# By
# fdaudens
# •
# 3 days ago
# •
# 10
# Daily Robotics June #1 - SmolVLA discovery and thoughts
# By
# Beegbrain
# •
# 6 days ago
# •
# 9
# AI Policy @🤗: Response to the 2025 National AI R&D Strategic Plan
# By
# evijit
# and 2 others
# •
# 7 days ago
# •
# 12
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 150
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 330
# Google Opensources Deep Research Agents using Gemini 2.5 & LangGraph, Let's Take a Look
# By
# lynn-mikami
# •
# 6 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 607
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 187
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 284
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 12 days ago
# •
# 20
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 89
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 41
# System Prompt Learning: Teaching LLMs to Learn Problem-Solving Strategies from Experience
# By
# codelion
# •
# 8 days ago
# •
# 10
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 142
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Fine tuning gpt-neo 2.7B with Lora on GSM8K - improve performance
# Beginners
# 2
# 12
# June 9, 2025
# LevelBot can't see my Discord user ID
# Beginners
# 4
# 11
# June 9, 2025
# 404 Page Not Found when accessing the "Multiple Choice Quiz" in the "Exam Time!" section of the LLM Course (Section 11: Fine-Tune Large Language Models)
# Course
# 2
# 10
# June 9, 2025
# Error while initializing ZeroGPU
# Models
# 3
# 10
# June 9, 2025
# Linux. Transfer ISOs
# Beginners
# 3
# 10
# June 9, 2025
# Networking, group chats, advertising
# Beginners
# 2
# 8
# June 9, 2025
# Using dataset for classifier with mutiple categories
# Beginners
# 3
# 9
# June 9, 2025
# Ajay Hinduja Geneva : How Can I Integrate a Mobile App with My Travel Website?
# Beginners
# 1
# 9
# June 9, 2025
# NotImplementedError when loading dataset with Streamlit
# 🤗Datasets
# 7
# 9786
# June 9, 2025
# How was self.loss_function implemented
# 🤗Transformers
# 3
# 7
# June 9, 2025
# Do AI apps need search engine optimization?
# Beginners
# 2
# 9
# June 9, 2025
# Not been able to add POST api method using Flask
# Beginners
# 2
# 12
# June 9, 2025
# It is your own script/code, surely it will work, right?
# Beginners
# 2
# 22
# June 8, 2025
# Efficient batch inference using stacked past_key_values for multiple continuation candidates
# Models
# 0
# 8
# June 9, 2025
# Problem Summary: Hugging Face Space Running, but Line Webhook Verification Fails with No Logs
# Beginners
# 1
# 15
# June 8, 2025
# Simplifying Hugging Face Spaces API calls in Flutter using hugging_face_chat_gradio package
# Intermediate
# 4
# 29
# June 8, 2025
# Tribit: A 36-Bit Symbolic Compression System for Tokenization, Reasoning, and Command Encoding
# 🤗Datasets
# 2
# 6
# June 9, 2025
# Introducing Tribit – A Symbolic Compression System for Language, Code, and Execution
# Research
# 2
# 9
# June 9, 2025
# Error handling POST request to Flask API route which uses pandas to read payload
# Beginners
# 0
# 5
# June 9, 2025
# HF auto train dataset load_metric error
# Beginners
# 33
# 75
# June 5, 2025
# A professionally translating LLM?
# Beginners
# 1
# 13
# June 9, 2025
# Can I ask a question if I have a good idea but can't write programs?
# Beginners
# 41
# 253
# June 3, 2025
# My Thoughts on Ollama (for a Serious Project) 🚀
# Beginners
# 2
# 48
# June 7, 2025
# Setfit trainer doesn't appear to be changing any weights
# Beginners
# 1
# 9
# June 8, 2025
# Segmant Anything Model (SAM) ValueError: Invalid image type
# Models
# 1
# 8
# June 8, 2025
# Account Issue: New API Tokens all fail with 401 Unauthorized Error
# Beginners
# 1
# 9
# June 8, 2025
# How to implement bind_tools to custom LLM from huggingface pipeline(Llama-3) for a custom agent
# Intermediate
# 3
# 1221
# June 9, 2025
# AI implementation with raspberry pi mini
# Beginners
# 1
# 18
# June 7, 2025
# Can't submit my paper to daily papers
# 🤗Hub
# 2
# 39
# June 9, 2025
# Inference API stopped working
# Inference Endpoints on the Hub
# 50
# 2906
# June 8, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 50k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 145k
# 29.3k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.3k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.3k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.7k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.8k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 544
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 320 repositories
# optimum-habana
# Public
# Easy and lightning fast training of 🤗 Transformers on Habana Gaudi processor (HPU)
# huggingface/optimum-habana’s past year of commit activity
# Python
# 188
# Apache-2.0
# 258
# 17
# (1 issue needs help)
# 40
# Updated
# Jun 9, 2025
# chat-ui
# Public
# Open source codebase powering the HuggingChat app
# huggingface/chat-ui’s past year of commit activity
# TypeScript
# 8,822
# Apache-2.0
# 1,332
# 315
# (1 issue needs help)
# 15
# Updated
# Jun 9, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 14,097
# Apache-2.0
# 1,949
# 397
# 80
# Updated
# Jun 9, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 145,366
# Apache-2.0
# 29,282
# 1,050
# (2 issues need help)
# 776
# Updated
# Jun 9, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,814
# Apache-2.0
# 1,123
# 82
# (4 issues need help)
# 20
# Updated
# Jun 9, 2025
# optimum-neuron
# Public
# Easy, fast and very cheap training and inference on AWS Trainium and Inferentia chips.
# huggingface/optimum-neuron’s past year of commit activity
# Jupyter Notebook
# 228
# Apache-2.0
# 76
# 11
# 8
# Updated
# Jun 9, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 29,298
# Apache-2.0
# 6,012
# 500
# (12 issues need help)
# 195
# Updated
# Jun 9, 2025
# hub-docs
# Public
# Docs of the Hugging Face Hub
# huggingface/hub-docs’s past year of commit activity
# Handlebars
# 396
# Apache-2.0
# 316
# 105
# 25
# Updated
# Jun 9, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 112
# Apache-2.0
# 13
# 5
# 8
# Updated
# Jun 9, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 14,260
# Apache-2.0
# 1,789
# 239
# 150
# Updated
# Jun 9, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 548 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We‚Äôre on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# 984,509 followers
# 6h
# Report this post
# ü¶æü¶æü¶æ
# Clem Delangue ü§ó
# Clem Delangue ü§ó is an Influencer
# Co-founder & CEO at Hugging Face
# 9h
# This weekend, thousands will learn, build, train & play with AI robots simultaneously from 100 different cities worldwide in what is turning out to be the biggest robotics hackathon ever organized, thanks to LeRobot.
#
# Let's make history!
# 51
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at ü§ó
# 12h
# Report this post
# I built an MCP server for the Hugging Face ecosystem üöÄ
#
# Inspired by
# Hugging Face
# 's official MCP server, I've developed a complementary tool that exposes my semantic search API to enhance discovery across the HF platform.
#
# Key capabilities:
#
# - AI-powered semantic search for models and datasets
# - Parameter count analysis via safetensors metadata
# - Trending content discovery
# - Find similar models/datasets functionality
# - 11 tools total for enhanced ecosystem navigation
#
# The semantic search goes beyond simple keyword matching, understanding context and relationships between different models and datasets.
#
# Example query: "Find around 10 reasoning Hugging Face datasets published in 2025 focusing on topics other than maths and science. Show a link and a short summary for each dataset." (results in video!)
# https://lnkd.in/eFi8PS87
# ‚Ä¶more
# 126
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,630 followers
# 1d
# Report this post
# Keep it up folks üî•
# ‚Ä¶more
# 59
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,630 followers
# 3d
# Report this post
# üéâ HACKATHON UPDATE: Extended Deadline by 2 Days Due to Incredible Response!
# We're thrilled to announce a 2-day extension for the Gradio Agents & MCP Hackathon due to overwhelming community participation!
#
# NEW DEADLINE: June 10, 2025 (Tuesday) UTC EOD
#
# üí™ The response has been phenomenal:
# 4100+ developers actively building
# 200+ projects in development
# $1M+ in API credits being utilized
# $16,500 in cash prizes across 3 tracks
#
# This extension gives our amazing community more time to polish their AI agents, MCP servers, and custom Gradio components.
#
# Three Competition Tracks:
# üîß MCP Server Development
# üõ†Ô∏è Custom Gradio Components
# ü§ñ Agentic AI Demonstrations
#
# Whether you're building a supercool AI Agents or sturdy MCP Servers, there's still time to participate and win.
#
# Join the Huggingface Organization page:
# https://lnkd.in/g7yp9HKG
# Discord:
# https://lnkd.in/gnxTPZvB
# Who's ready to WIN? üíØ
# 40
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 3d
# Report this post
# Today is a big day, we're introducing the first version of the HF MCP server üî•
#
# Connect to the Hub APIs programmatically from your LLM, directly from
# - VSCode,
# - Cursor,
# - Claude Desktop,
# - or any other MCP-powered app
#
# We expose:
# 1Ô∏è‚É£ a curated set of built-in tools like Spaces and Papers Semantic Search, Model and Dataset exploration, etc
# 2Ô∏è‚É£ even cooler, we expose a dynamic list of all MCP-compatible
# Gradio
# apps hosted on Spaces ü§Ø
#
# And... the server is open source! Built by
# Shaun Smith
# and the
# Hugging Face
# team üíì
#
# Link to get started in the first comment ‚§µÔ∏è
# 2,859
# 103 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,630 followers
# 3d
# Edited
# Report this post
# Finally, it is here!!! > Access the
# Hugging Face
# Hub through your LLMs
#
# Checkout our changelog for more:
# https://lnkd.in/gT-UX79R
# ü§Ø Join the Biggest ever Agents-MCP Hackathon here and win Cash prizes ranging from $500 to $5000:
# https://lnkd.in/g7yp9HKG
# 49
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Amir Mahla
# Building agents @ Hugging Face ü§ó
# 3d
# Edited
# Report this post
# üöÄ Excited to announce we're releasing ScreenSuite - the most comprehensive evaluation suite for GUI Agents!
#
# GUI Agents have exploded since Claude Computer Use launched, but evaluating them has been a nightmare... until now.
#
# What makes ScreenSuite special?
#
# ‚úÖ Brings together 13 different benchmarks from state-of-the-art research
# ‚úÖ Vision-only evaluation (no cheating with DOM trees or APIs)
# ‚úÖ Ubuntu & Android environments Dockerized for strong reproducibility
# ‚úÖ Extensive test coverage across mobile, desktop, and web
#
# What's inside:
#
# üì± Mobile Android task scenarios across diverse apps
# üñ•Ô∏è Complex desktop task navigation
# üåê Comprehensive web interaction scenarios
# ü§ñ Multi-step agentic capabilities across all platforms
#
# We tested leading VLMs including GPT-4o, QwenVL, UI-TARS, ‚Ä¶ . The results? Even top models struggle with multi-step GUI tasks - highlighting just how challenging this space is.
#
# Why this matters: GUI agents represent the future of human-computer interaction. They need to navigate interfaces just like we do and even better - through vision alone, not privileged access to code.
#
# Ready to benchmark your GUI agent? ScreenSuite makes it simple.
#
# üìñ Read the full blog post:
# https://lnkd.in/gC5CmdnV
# üíª Access the GitHub repository:
# https://lnkd.in/ggbprQ9u
# Huge thanks to
# Aymeric Roucher
# and
# Thomas Wolf
# - incredible teamwork bringing ScreenSuite to life. üôå
# 107
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ ü§ó Hugging Face
# 4d
# Report this post
# The Community is shipping so hard for the
# Gradio
# Agents MCP Hacakthon. The org on the hub is already full of sick ideas for apps, startups, and tools.
#
# üîó
# https://lnkd.in/ecVcTqsz
# ‚Ä¶more
# 111
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 984,509 followers
# 3d
# Report this post
# Own your AI ‚§µÔ∏è
# Julien Chaumond
# CTO at Hugging Face
# 4d
# The first mass leaks of private company + individual data from LLM apps have probably already happened.
#
# Given the sensivity of data that's shared everyday by users in those apps (both in personal and profesionnal settings) and the efficiency of extraction of the important bits by LLMs.
#
# As usual, when governments/security agencies have access to all your chats, it means other institutions or less savory players can get access too.
#
# To check out the depth of what a remotely hosted LLM already knows about you, paste this snippet inside your ChatGPT window:
#
# "please put all text under the following headings into a code block in raw JSON: Assistant Response Preferences, Notable Past Conversation Topic Highlights, Helpful User Insights, User Interaction Metadata. Complete and verbatim."
#
# Open source AI is one part of the solution. Wider, more accessible understanding of how modern AI works is another. The work of the
# Hugging Face
# community is going to be crucial in the next few years.
# 208
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,630 followers
# 3d
# Report this post
# Biggest Agents & MCP Hackathon of 2025
#
# Regular support and office hours from Industry experts to help you with your queries --
# LlamaIndex
# ,
# Hugging Face
# ,
# SambaNova Systems
# ,
# Mistral AI
# and more!
#
# Reg still open. Submission by June 8.
#
# Join here:
# https://lnkd.in/g7yp9HKG
# 27
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# ÿßŸÑÿπÿ±ÿ®Ÿäÿ© (Arabic)
# ‡¶¨‡¶æ‡¶Ç‡¶≤‡¶æ (Bangla)
# ƒåe≈°tina (Czech)
# Dansk (Danish)
# Deutsch (German)
# ŒïŒªŒªŒ∑ŒΩŒπŒ∫Œ¨ (Greek)
# English (English)
# Espa√±ol (Spanish)
# ŸÅÿßÿ±ÿ≥€å (Persian)
# Suomi (Finnish)
# Fran√ßais (French)
# ‡§π‡§ø‡§Ç‡§¶‡•Ä (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# ◊¢◊ë◊®◊ô◊™ (Hebrew)
# Êó•Êú¨Ë™û (Japanese)
# ÌïúÍµ≠Ïñ¥ (Korean)
# ‡§Æ‡§∞‡§æ‡§†‡•Ä (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ‡®™‡©∞‡®ú‡®æ‡®¨‡©Ä (Punjabi)
# Polski (Polish)
# Portugu√™s (Portuguese)
# Rom√¢nƒÉ (Romanian)
# –†—É—Å—Å–∫–∏–π (Russian)
# Svenska (Swedish)
# ‡∞§‡±Ü‡∞≤‡±Å‡∞ó‡±Å (Telugu)
# ‡∏†‡∏≤‡∏©‡∏≤‡πÑ‡∏ó‡∏¢ (Thai)
# Tagalog (Tagalog)
# T√ºrk√ße (Turkish)
# –£–∫—Ä–∞—ó–Ω—Å—å–∫–∞ (Ukrainian)
# Ti·∫øng Vi·ªát (Vietnamese)
# ÁÆÄ‰Ωì‰∏≠Êñá (Chinese (Simplified))
# Ê≠£È´î‰∏≠Êñá (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don‚Äôt have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-R1-0528\nUpdated\n11 days ago\n•\n97.1k\n•\n1.88k\nQwen/Qwen3-Embedding-0.6B-GGUF\nUpdated\nabout 18 hours ago\n•\n8.45k\n•\n257\ngoogle/gemma-3n-E4B-it-litert-preview\nUpdated\n15 days ago\n•\n1.05k\nResembleAI/chatterbox\nUpdated\n11 days ago\n•\n732\nfishaudio/openaudio-s1-mini\nUpdated\n7 days ago\n•\n1.25k\n•\n182\nBrowse 1M+ models\nSpaces\nRunning\non\nZero\n926\n926\nChatterbox TTS\n🍿\nExpressive Zeroshot TTS\nRunning\n7.84k\n7.84k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n575\n575\nWan2.1 Fast\n🎥\nTurn static images into animated videos\nRunning\non\nZero\n236\n236\nChain-of-Zoom\n🚀\nExtreme Super-Resolution via Scale Autoregression\nRunning\n478\n478\nRealistic Text To Speech Unlimited\n🔥\nFree Text-To-Speech generator with Emotion control (OpenAI)\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n20.9k\n•\n7.89k\nopen-thoughts/OpenThoughts3-1.2M\nUpdated\nabout 7 hours ago\n•\n3.7k\n•\n68\nyandex/yambda\nUpdated\n3 days ago\n•\n39.6k\n•\n153\nHcompany/WebClick\nUpdated\nabout 7 hours ago\n•\n3.56k\n•\n45\na-m-team/AM-DeepSeek-R1-0528-Distilled\nUpdated\nabout 9 hours ago\n•\n2.5k\n•\n44\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n765 models\n•\n3.39k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.15k models\n•\n6.35k followers\nAmazon\ncompany\n•\n20 models\n•\n3.22k followers\nGoogle\ncompany\n•\n997 models\n•\n16.2k followers\nIntel\ncompany\n•\n230 models\n•\n2.62k followers\nMicrosoft\ncompany\n•\n386 models\n•\n12.8k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n162 followers\nWriter\nEnterprise\ncompany\n•\n22 models\n•\n294 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n145,366\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,298\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,298\nSafe way to store/distribute neural network weights\nHub Python Library\n2,675\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,774\nFast tokenizers optimized for research & production\nTRL\n14,097\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,766\nState-of-the-art ML running directly in your browser\nsmolagents\n19,925\nSmol library to build great agents in Python\nPEFT\n18,712\nParameter-efficient finetuning for large language models\nDatasets\n20,2 ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **Hugging Face** is the AI community building the future. We provide a platform where machine learning enthusiasts and professionals collaborate on various models, datasets, and applications. Our passion lies in creating an open and innovative environment that fosters the next wave of AI advancements.
#
# ---
#
# ### Company Overview
# - **Launch**: Established as a key player in artificial intelligence and machine learning.
# - **Mission**: To make machine learning better and more accessible for everyone around the globe.
# - **Community Engagement**: With over 50,000 organizations using our platform, we are building strong ties with industry leaders and fostering a collaborative approach to innovation.
#
# ---
#
# ### What We Offer
# - **Models**: Explore and share from over 1 million models, including trending innovations in machine learning such as timing prediction, text-to-speech, and more.
# - **Datasets**: Access to a vast library of over 250,000 datasets tailored for various ML tasks.
# - **Spaces**: Create, discover, and showcase innovative applications. Find apps for text generation, image manipulation, and much more!
# - **Enterprise Solutions**: Serve your team with advanced AI capabilities. We offer enterprise-grade security, support, and tools for seamless integration.
#
# ---
#
# ### Our Culture
# At **Hugging Face**, we nurture a community-driven culture that values collaboration, transparency, and enthusiasm for AI. Our workforce comprises over 215 dedicated team members who are deeply engaged in pushing the boundaries of what is possible in machine learning. We encourage continuous learning and thriving creativity—ideal for those passionate about AI!
#
# ---
#
# ### Join Us
# **Careers at Hugging Face**: We are always on the lookout for talented and motivated individuals who share our vision of developing cutting-edge ML solutions. Here’s how you can contribute:
#
# - **Open Positions**: Check our [Jobs Page](https://huggingface.co/jobs) for current opportunities.
# - **Networking**: Join our vibrant community through [Discord](https://huggingface.co/discord), [GitHub](https://huggingface.co/github), and social media.
#
# ---
#
# ### Our Customers
# From startups to industry giants, our clientele includes renowned organizations such as:
# - **Google**
# - **Microsoft**
# - **Amazon**
# - **Intel**
# - Industry-leading non-profits like AI2 and platforms ranging from gaming to healthcare.
#
# ---
#
# ### Get in Touch
# Stay connected and keep up with all the latest developments in AI at Hugging Face!
# - Follow us on [Twitter](https://twitter.com/huggingface) and [LinkedIn](https://www.linkedin.com/company/huggingface).
# - Explore our resources and documentation at [Hugging Face Docs](https://huggingface.co/docs).
#
# Together, let’s build the future of AI!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ### The AI Community Building the Future
#
# **Welcome to Hugging Face!**
# At Hugging Face, we are dedicated to creating a collaborative platform at the heart of the machine learning community. Our mission is to empower individuals and organizations to explore and develop cutting-edge AI models, datasets, and applications, shaping the future of technology together.
#
# ---
#
# ## **What We Offer**
#
# ### **Models**
# - **Explore Over 1 Million Models**: Collaborate, develop, and share your models with the world. From NLP to computer vision, our library includes a diverse set of state-of-the-art AI models.
#
# ### **Datasets**
# - **Access to 250k+ Datasets**: Browse an extensive collection of datasets tailored for various machine learning tasks. Share your datasets and connect with researchers and developers.
#
# ### **Spaces**
# - **Collaborative Application Development**: Utilize our platform to host and run applications seamlessly. Tools such as Chatterbox TTS and DeepSite empower users to create innovative solutions quickly.
#
# ### **Enterprise Solutions**
# - **Robust Support for Organizations**: With dedicated resources for enterprises, we provide the most advanced AI platform ensuring enterprise-grade security and support starting at $20/user/month.
#
# ---
#
# ## **Community Engagement**
# At Hugging Face, our community thrives on collaboration. More than 50,000 organizations, including tech giants like Google, Microsoft, and Amazon, are part of our ecosystem. Together, we contribute to an open-source foundation that drives machine learning innovation.
#
# ### **Open Source Contributions**
# - **Transformers, Tokenizers, Diffusers & More**: Our open-source projects are built with community input, providing tools for model training, data access, and efficient production deployment.
#
# ---
#
# ## **Company Culture**
# - **Inclusive & Collaborative**: We are a community-driven organization that values diversity and the power of collaboration. Our culture promotes open dialogue and collective success, making it a vibrant place to work.
#
# - **Cutting-Edge Innovation**: Hugging Face is also a place for innovation where every team member's ideas are welcomed. We encourage creativity and exploration, cultivating the next generation of AI advancements.
#
# ---
#
# ## **Careers at Hugging Face**
# ### **Join Our Team!**
# We are constantly on the lookout for talented individuals who share our passion for AI. At Hugging Face, you'll have the opportunity to work with leading minds in machine learning, contribute to exciting projects, and shape the future of the AI landscape. Our positions span across various domains, including software development, research, community engagement, and more.
#
# ---
#
# **Connect with Us!**
# Ready to dive into the world of AI? Whether you're a prospective customer, an investor, or a future member of our team, we invite you to explore our platform and become part of the Hugging Face community.
#
# **Explore**: [Hugging Face Site](https://huggingface.co)
#
# ---
#
# ### **Follow Us Where Technology Meets Community!**
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://discord.com/invite/huggingface)
#
# Together, let's build the future of AI!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # 💖 Hugging Face: The Future of AI and Hugs! 🤗
#
# Welcome to Hugging Face! Where we harness the cuddly powers of artificial intelligence to deliver models, datasets, and applications, packed with more love than a puppy parade! 🐶
#
# ---
#
# ## 🌍 Join the AI Community Revolution!
#
# At Hugging Face, we believe in collaboration—just like a good game of telephone, but with machine learning. 🎤🔄 Whether you're a business mogul or a curious cat, there’s something for everyone in our friendly AI playground.
#
# **You'll find:**
#
# - **1M+ Models:** That’s right! Just like collecting Pokémon cards, but for algorithms!
# - **250k+ Datasets:** The buffet you never knew you needed to fuel your ML cravings! 🍽️
# - **400k+ Applications:** Whether you want to turn your high school photos into animated videos or speak like a pro at any event (thanks, text-to-speech), we’ve got it covered!
#
# ---
#
# ## 👔 Fancy a Career at Hugging Face?
#
# Are you looking to join a company where “office politics” is as casual as choosing the right emoji for your Slack message? Here, we embrace creativity humanely… and with a side of fun!
#
# **Why work with us?**
# - **Happy Team Spirit:** We have a team of 215+ happy faces (just like ours) and we aim to double that number! 😉
# - **Advanced Tools:** Enjoy playing with our state-of-the-art ML tools while your colleagues happily cheer from the sidelines—it's like a digital pep rally! 🤩
# - **Flexibility:** Work from anywhere because your best ideas might strike in your pajamas on a Tuesday!
#
# ---
#
# ## 🤝 Our Customers: Big and Small!
#
# Are you in good company? 50,000+ organizations think so! Here are some fans among the heavyweights:
#
# - **Google**: Where better algorithms are just a Hugging Face away! 🤖
# - **Amazon**: We deliver models faster than their Prime shipping! 📦
# - **Microsoft, Grammarly, and Intel:** Just a few of our fans who swear by us (and some might even say they’ve fallen in love! 💘).
#
# ---
#
# ## 🤗 Wrap Up
#
# Set against the backdrop of camaraderie and innovation, Hugging Face isn’t just building models, we are building futures—filled with AI hugs. 🌈
#
# **So whether you’re a customer, investor, or future recruit, grab your virtual hug today!** Because at Hugging Face, we don’t just code; we create, collaborate, and, above all, care! 🥳
#
# Let’s embrace the future together! Sign up today at [Hugging Face](https://huggingface.co)!
#
# ---
#
# *Disclaimer: Hugs are metaphorical and AI models do not actually hug.*

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
